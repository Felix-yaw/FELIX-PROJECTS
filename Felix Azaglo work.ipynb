# %% [markdown]
# # Name : Felix Azaglo Yaw
# # ID Number : 10951571
# # Programme :Computer Engineering
# # PYTHON DATA ANAYSIS PROJECT

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sbn

# %%
data = pd.read_csv('data.csv')

# %% [markdown]
# # OVERVIEW OF DATA

# %%
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB
# None

# %% [markdown]
# # CHECKING FOR NULL CELLS

# %%
print(data.isnull().sum())
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# # Checking for number of duplicates

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # Filling all null cells with mean values of the already filled cells
# ### This action is taken so that data is not lost since the data is always better kept than deleted for reasons unforeseen in the future.Hence the null cells are filled with mean of all values in oder to establish correlation with existing data in the cells
# ## Filling null cells with mean values is a common technique used in data analysis to handle missing data. This is because null or missing data can cause problems in statistical analysis and can result in biased or incomplete results.
#
# ## By filling the null cells with the mean of all values, we are preserving the statistical properties of the data, such as the mean and standard deviation. This helps to maintain the overall distribution of the data and ensures that the analysis is based on the most complete dataset possible.
#
# ## Additionally, filling null cells with mean values can also help to reduce the impact of outliers or extreme values, which can skew the results of the analysis. By replacing null cells with the mean, we are essentially smoothing out the dataset and making it more representative of the underlying distribution.

# %%
everyColumn = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides','free sulfur dioxide', 'total sulfur dioxide','density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
for column in everyColumn:
    data[column].fillna(data[column].mean(), inplace=True)

# %%
print(data.isnull().sum())
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# # DRAWING OF STATISTICAL INFERENCES
# ## Histograms for each column

# %%
Dropped_id = data.drop('ID', axis=1)
Dropped_id.hist(figsize=(12, 10), color='yellow')
plt.show()

# %% [markdown]
# # Line graph for each column indicating the quality of dataset.

# %%
everyColumn = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides','free sulfur dioxide', 'total sulfur dioxide','density', 'pH', 'sulphates', 'alcohol']
plt.figure(figsize=(12,7))
for column in everyColumn:
    plt.title(f'Quality graph for {column}')
    sns.lineplot(x='quality', y=column, data=data)
    plt.show()

# %% [markdown]
# #   Correlation between other quantitites and quality

# %%
acids = ['fixed acidity', 'citric acid', 'volatile acidity']

# %%
for acid in acids :
    plt.title(f'Correlation between {acid} and the pH')
    sbn.scatterplot(x=acid, y = 'pH', data=data)
    plt.figure(figsize=(12,10))
    plt.show()

# %%
columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides',
           'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

for column in columns:
    data[column].mean()
    comparing_means = data[column] < data[column].mean()
    colors = ['#1f77b4', '#2ca02c'] # blue and green colors
    plt.pie(comparing_means.value_counts(), labels=['Values less than the mean', 'Values greater than the mean'],
            colors=colors)
    plt.title(f'Comparison between {column} values and the {column} mean')
    plt.show()

# %% [markdown]
# # DISPLAY OF HIDDEN INFERENCES USING PAIRPLOT

# %%
colors = ['#2ecc71', '#2ecc71']
sbn.set_palette(sbn.color_palette(colors))

sbn.pairplot(data=data, vars=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides'], diag_kws={'color': colors[0]}, plot_kws={'color': colors[1]})

# %% [markdown]
# # Data correlation using Heat Maps

# %%
correlation_matrix = data.corr()

my_cmap = sbn.color_palette(['#bcbddc', '#9e9ac8', '#807dba', '#6a51a3', '#4a1486'])


sbn.heatmap(correlation_matrix, annot=True, cmap=my_cmap)

plt.figure(figsize=(13, 6))

plt.show()

# %%
sbn.kdeplot(data=data, shade=True)
plt.show
fig, axes = plt.subplots(nrows=len(data.columns), ncols=1, figsize=(10, 16))
for i, col in enumerate(data.columns):
    sbn.kdeplot(ax=axes[i], data=data[col], shade=True)
    axes[i].set_xlabel(col)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9432\2922687057.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(data=data, shade=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9432\2922687057.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(ax=axes[i], data=data[col], shade=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9432\2922687057.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sbn.kdeplot(ax=axes[i], data=data[col], shade=True)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9432\2922687057.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %% [markdown]
# # Box plot for the Dataset

# %%
sbn.set(style='whitegrid') 
sbn.boxplot(data=data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(9,7)) 
quality_counts = data['quality'].value_counts()
plt.pie(quality_counts.values, labels=quality_counts.index, autopct='%1.1f %%')
plt.title('Pie Chart of Quality')
plt.axis('equal')
plt.show()
